# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\Suchana Hazra\OneDrive\Desktop\ml projects\shopping_trends_updated(1).csv")

# %%
dataset.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
dataset.keys()
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
df = []

# %%
dataset.shape
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel('Item Purchased')
plt.ylabel('Amount of Purchase')
plt.bar(df['Item Purchased'],df['Previous Purchases'])
# Out:
# <BarContainer object of 3900 artists>

# %%
df = dataset.drop(['Location','Color','Size','Subscription Status','Shipping Type','Promo Code Used','Customer ID'], axis = 'columns')

# %%
df
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  Season  \
# 0      55    Male         Blouse     Clothing                     53  Winter
# 1      19    Male        Sweater     Clothing                     64  Winter
# 2      50    Male          Jeans     Clothing                     73  Spring
# 3      21    Male        Sandals     Footwear                     90  Spring
# 4      45    Male         Blouse     Clothing                     49  Spring
# ...   ...     ...            ...          ...                    ...     ...
# 3895   40  Female         Hoodie     Clothing                     28  Summer
# 3896   52  Female       Backpack  Accessories                     49  Spring
# 3897   46  Female           Belt  Accessories                     33  Spring
# 3898   44  Female          Shoes     Footwear                     77  Summer
# 3899   52  Female        Handbag  Accessories                     81  Spring
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
from word2number import w2n

# %%
df['Gender'] = le.fit_transform(df['Gender'])
df['Category'] = le.fit_transform(df['Category'])
df['Season'] = le.fit_transform(df['Season'])
df['Frequency_of_Purchases'] = le.fit_transform(df['Frequency of Purchases'])
df['Discount Applied'] = le.fit_transform(df['Discount Applied'])
df['Payment Method'] = le.fit_transform(df['Payment Method'])
df['Item Purchased'] = le.fit_transform(df['Item Purchased'])

# %%
df
# Out:
#       Age  Gender  Item Purchased  Category  Purchase Amount (USD)  Season  \
# 0      55       1               2         1                     53       3
# 1      19       1              23         1                     64       3
# 2      50       1              11         1                     73       1
# 3      21       1              14         2                     90       1
# 4      45       1               2         1                     49       1
# ...   ...     ...             ...       ...                    ...     ...
# 3895   40       0               9         1                     28       2
# 3896   52       0               0         0                     49       1
# 3897   46       0               1         0                     33       1
# 3898   44       0              17         2                     77       2
# 3899   52       0               7         0                     81       1
#
# ...

# %%
df.drop(['Frequency of Purchases'],axis = 'columns')
# Out:
#       Age  Gender  Item Purchased  Category  Purchase Amount (USD)  Season  \
# 0      55       1               2         1                     53       3
# 1      19       1              23         1                     64       3
# 2      50       1              11         1                     73       1
# 3      21       1              14         2                     90       1
# 4      45       1               2         1                     49       1
# ...   ...     ...             ...       ...                    ...     ...
# 3895   40       0               9         1                     28       2
# 3896   52       0               0         0                     49       1
# 3897   46       0               1         0                     33       1
# 3898   44       0              17         2                     77       2
# 3899   52       0               7         0                     81       1
#
# ...

# %%
df.describe()
# Out:
#                Age       Gender  Item Purchased     Category  \
# count  3900.000000  3900.000000     3900.000000  3900.000000
# mean     44.068462     0.680000       12.035385     1.001795
# std      15.207589     0.466536        7.199162     0.896688
# min      18.000000     0.000000        0.000000     0.000000
# 25%      31.000000     0.000000        6.000000     0.000000
# 50%      44.000000     1.000000       12.000000     1.000000
# 75%      57.000000     1.000000       18.000000     1.000000
# max      70.000000     1.000000       24.000000     3.000000
#
#        Purchase Amount (USD)       Season  Review Rating  Discount Applied  \
# count            3900.000000  3900.000000    3900.000000       3900.000000
# mean               59.764359     1.492821       3.749949          0.430000
# std                23.685392     1.117236       0.716223          0.495139
# min                20.000000     0.000000       2.500000          0.000000
# ...

# %%
df
# Out:
#       Age  Gender  Item Purchased  Category  Purchase Amount (USD)  Season  \
# 0      55       1               2         1                     53       3
# 1      19       1              23         1                     64       3
# 2      50       1              11         1                     73       1
# 3      21       1              14         2                     90       1
# 4      45       1               2         1                     49       1
# ...   ...     ...             ...       ...                    ...     ...
# 3895   40       0               9         1                     28       2
# 3896   52       0               0         0                     49       1
# 3897   46       0               1         0                     33       1
# 3898   44       0              17         2                     77       2
# 3899   52       0               7         0                     81       1
#
# ...

# %%
df
# Out:
#       Age  Gender  Item Purchased  Category  Purchase Amount (USD)  Season  \
# 0      55       1               2         1                     53       3
# 1      19       1              23         1                     64       3
# 2      50       1              11         1                     73       1
# 3      21       1              14         2                     90       1
# 4      45       1               2         1                     49       1
# ...   ...     ...             ...       ...                    ...     ...
# 3895   40       0               9         1                     28       2
# 3896   52       0               0         0                     49       1
# 3897   46       0               1         0                     33       1
# 3898   44       0              17         2                     77       2
# 3899   52       0               7         0                     81       1
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel('Item Purchased')
plt.ylabel('Amount of Purchase')
plt.bar(df['Item Purchased'],df['Previous Purchases'])
# Out:
# <BarContainer object of 3900 artists>
